# %%
import numpy as np

# %%
a = np.array([1,2,3])
print (a)
# Out:
# [1 2 3]

# %%
b = np.array([[1,2,3],[4,5,6]])
print (b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#get dimention
b.ndim
# Out:
# 2

# %%
# get shape
b.shape
# Out:
# (2, 3)
